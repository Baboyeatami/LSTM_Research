# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from math import sqrt

# Load dataset
data = pd.read_csv('Cleaned_MCS_TEAM_DATA.csv')

# Convert 'DATETIME' to datetime object
data['DATETIME'] = pd.to_datetime(data['DATETIME'])

# Sort dataset by date
data = data.sort_values(by='DATETIME')
print(data.columns)


# Encode categorical variables
le_condition = LabelEncoder()
le_flood = LabelEncoder()
data['ACTUAL CONDITION'] = le_condition.fit_transform(data['ACTUAL CONDITION'])
data['OCCURENCE OF FLOOD'] = le_flood.fit_transform(data['OCCURENCE OF FLOOD'])

# Set DATETIME as index
data.set_index('DATETIME', inplace=True)

# Resample to hourly data (assuming original data is at an interval of every 8 hours)
data = data.resample('h').mean().interpolate()  # Interpolating to fill gaps

# Features to forecast
features = ['TEMPERATURE (°C)', 'RAINFALL (mm)', 'ACTUAL CONDITION', 'OCCURENCE OF FLOOD']

# Function to fit SARIMA model and make forecasts
def fit_sarima(data, feature, order, seasonal_order, steps):
    model = SARIMAX(data[feature], order=order, seasonal_order=seasonal_order)
    results = model.fit(disp=True)
    forecast = results.forecast(steps)
    return forecast

# Parameters for SARIMA model (p, d, q) and seasonal parameters (P, D, Q, S)
p, d, q = 1, 1, 1  # Example parameters for non-seasonal part
P, D, Q, S = 1, 1, 1, 24  # Example parameters for seasonal part (e.g., daily seasonality)

# Forecast the next 7 days (7 * 24 = 168 hours) for each feature
n_future = 168  # 7 days of hourly data
forecasts = {}

for feature in features:
    forecasts[feature] = fit_sarima(data, feature, (p, d, q), (P, D, Q, S), n_future)

# Create a DataFrame for the forecasted data
forecast_dates = pd.date_range(start=data.index.max() + pd.Timedelta(hours=8), periods=n_future, freq='8H')
forecast_df = pd.DataFrame(forecasts, index=forecast_dates)
forecast_df.to_csv('ARIMA_forecast_results.csv', index=True) 
# Plotting the forecast results
plt.figure(figsize=(14, 10))
for feature in features:
    plt.subplot(2, 2, features.index(feature) + 1)
    plt.plot(data[feature], label='Historical', color='blue')
    plt.plot(forecast_df[feature], label='Forecast', color='orange')
    plt.title(f'Forecast for {feature}')
    plt.xlabel('Date')
    plt.ylabel(feature)
    plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Index(['DATETIME', 'TEMPERATURE (°C)', 'RAINFALL (mm)', 'ACTUAL CONDITION',
#        'OCCURENCE OF FLOOD'],
#       dtype='object')
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.24887D-01    |proj g|=  4.78990D-01
#
# At iterate    1    f=  6.88362D-01    |proj g|=  4.46240D-01
#
# At iterate    2    f=  6.70485D-01    |proj g|=  1.18891D-01
#
# At iterate    3    f=  6.66031D-01    |proj g|=  1.23324D-01
#
# At iterate    4    f=  6.40264D-01    |proj g|=  4.99235D-01
#
# At iterate    5    f=  6.16607D-01    |proj g|=  5.39520D-01
#
# At iterate    6    f=  5.81911D-01    |proj g|=  2.02086D-01
#
# At iterate    7    f=  5.74087D-01    |proj g|=  8.44378D-02
#
# At iterate    8    f=  5.69928D-01    |proj g|=  1.50289D-02
#
# At iterate    9    f=  5.68407D-01    |proj g|=  1.08313D-02
#
# ...

# %%
# Load actual data for comparison

actual_data = pd.read_csv('Actual.csv')
actual_data['DATETIME'] = pd.to_datetime(actual_data['DATETIME'])

# Plotting the actual vs forecasted data
plt.figure(figsize=(14, 12))
print(forecast_df.index)
# Plot Temperature
plt.subplot(4, 1, 1)
plt.plot(actual_data['DATETIME'], actual_data['TEMPERATURE (°C)'], label='Actual Temperature', color='blue')
plt.plot(forecast_df.index, forecast_df['TEMPERATURE (°C)'], label='Forecasted Temperature', color='orange')
plt.title('Temperature Forecast vs Actual')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.legend()

# Plot Rainfall
plt.subplot(4, 1, 2)
plt.plot(actual_data['DATETIME'], actual_data['RAINFALL (mm)'], label='Actual Rainfall', color='blue')
plt.plot(forecast_df.index, forecast_df['RAINFALL (mm)'], label='Forecasted Rainfall', color='orange')
plt.title('Rainfall Forecast vs Actual')
plt.xlabel('Date')
plt.ylabel('Rainfall (mm)')
plt.legend()

# Plot Actual Condition
plt.subplot(4, 1, 3)
plt.plot(actual_data['DATETIME'], actual_data['ACTUAL CONDITION'], label='Actual Condition', color='blue', marker='o', markersize=2)
plt.plot(forecast_df.index, forecast_df['ACTUAL CONDITION'], label='Forecasted Condition', color='orange', marker='x', markersize=2)
plt.title('Actual Condition vs Forecasted Condition')
plt.xlabel('Date')
plt.ylabel('Actual Condition')
plt.xticks(rotation=45)
plt.legend()

# Plot Occurrence of Flood
plt.subplot(4, 1, 4)
plt.plot(actual_data['DATETIME'], actual_data['OCCURENCE OF FLOOD'], label='Actual Occurrence of Flood', color='blue', marker='o', markersize=2)
plt.plot(forecast_df.index, forecast_df['OCCURENCE OF FLOOD'], label='Forecasted Occurrence of Flood', color='orange', marker='x', markersize=2)
plt.title('Occurrence of Flood vs Forecasted Occurrence of Flood')
plt.xlabel('Date')
plt.ylabel('Occurrence of Flood')
plt.xticks(rotation=45)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# DatetimeIndex(['2024-09-01 00:00:00', '2024-09-01 08:00:00',
#                '2024-09-01 16:00:00', '2024-09-02 00:00:00',
#                '2024-09-02 08:00:00', '2024-09-02 16:00:00',
#                '2024-09-03 00:00:00', '2024-09-03 08:00:00',
#                '2024-09-03 16:00:00', '2024-09-04 00:00:00',
#                ...
#                '2024-10-23 16:00:00', '2024-10-24 00:00:00',
#                '2024-10-24 08:00:00', '2024-10-24 16:00:00',
#                '2024-10-25 00:00:00', '2024-10-25 08:00:00',
#                '2024-10-25 16:00:00', '2024-10-26 00:00:00',
#                '2024-10-26 08:00:00', '2024-10-26 16:00:00'],
#               dtype='datetime64[ns]', length=168, freq='8h')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Load the actual data from 'Actual.csv'
actual_data = pd.read_csv('Actual.csv')

# Convert 'DATETIME' columns to datetime objects for proper plotting and indexing
actual_data['DATETIME'] = pd.to_datetime(actual_data['DATETIME'])
forecast_df.index = pd.to_datetime(forecast_df.index)
print(forecast_df)

# Set the 'DATETIME' column as the index for both DataFrames
actual_data.set_index('DATETIME', inplace=True)
#forecast_df.set_index('DATETIME', inplace=True)

# Ensure that the indices align for comparison
common_index = actual_data.index.intersection(forecast_df.index)
actual_data = actual_data.loc[common_index]
forecast_df = forecast_df.loc[common_index]

# Check if the data is aligned properly
if actual_data.empty or forecast_df.empty:
    print("Error: No common indices found between actual and forecast data.")
else:
    # Calculate performance metrics
    metrics = {}
    for column in actual_data.columns:
        if column in forecast_df.columns:
            y_true = actual_data[column]
            y_pred = forecast_df[column]
            mae = mean_absolute_error(y_true, y_pred)
            rmse = np.sqrt(mean_squared_error(y_true, y_pred))
            metrics[column] = {'MAE': mae, 'RMSE': rmse}
            print(f"{column} - MAE: {mae:.2f}, RMSE: {rmse:.2f}")

    # Plot actual vs forecasted values for visual comparison
    for column in actual_data.columns:
        if column in forecast_df.columns:
            plt.figure(figsize=(12, 6))
            plt.plot(actual_data.index, actual_data[column], label='Actual', color='blue')
            plt.plot(forecast_df.index, forecast_df[column], label='Forecast', color='red', linestyle='--')
            plt.title(f'Actual vs Forecast for {column}')
            plt.xlabel('Date')
            plt.ylabel(column)
            plt.legend()
            plt.grid(True)
            plt.show()
# Out:
#                      TEMPERATURE (°C)  RAINFALL (mm)  ACTUAL CONDITION  \
# 2024-09-01 00:00:00         31.065212       0.915441          0.571606
# 2024-09-01 08:00:00         30.130412       1.998347          0.633451
# 2024-09-01 16:00:00         32.099685      -0.190340          0.415287
# 2024-09-02 00:00:00         31.326936       0.933259          0.511948
# 2024-09-02 08:00:00         30.339131       2.065507          0.588516
# ...                               ...            ...               ...
# 2024-10-25 08:00:00               NaN            NaN               NaN
# 2024-10-25 16:00:00               NaN            NaN               NaN
# 2024-10-26 00:00:00               NaN            NaN               NaN
# 2024-10-26 08:00:00               NaN            NaN               NaN
# 2024-10-26 16:00:00               NaN            NaN               NaN
#
#                      OCCURENCE OF FLOOD
# 2024-09-01 00:00:00            0.979543
# ...

# %% [markdown]
# Forecasting Report on ARIMA Model Performance
# Introduction
# This report provides an analysis of the forecasting performance of the ARIMA (AutoRegressive Integrated Moving Average) model based on the specified metrics for various weather-related variables: Temperature, Rainfall, Actual Condition, and Occurrence of Flood. Understanding the model's performance is crucial for evaluating its effectiveness in predicting future events and for making informed decisions based on these forecasts.
#
# Performance Metrics Overview
# The performance of the ARIMA model is evaluated using two key metrics for each variable: Mean Absolute Error (MAE) and Root Mean Square Error (RMSE). These metrics provide insights into the accuracy of the model's predictions.
#
# Temperature (°C)
#
# MAE: 5.93
# RMSE: 6.55
# Analysis: The MAE indicates that, on average, the predicted temperature deviates from the actual values by approximately 5.93°C. The RMSE, being slightly higher at 6.55°C, suggests that there are larger errors present in some predictions. The difference between MAE and RMSE indicates that there may be some outliers affecting the predictions, warranting further investigation.
# Rainfall (mm)
#
# MAE: 1.13
# RMSE: 1.45
# Analysis: The MAE for rainfall forecasts is relatively low, indicating that the model's predictions are closely aligned with actual rainfall measurements. The RMSE is also low, suggesting consistent accuracy in predicting rainfall amounts. This performance is promising for applications where accurate rainfall forecasting is critical, such as agriculture and flood management.
# Actual Condition
#
# MAE: 4.22
# RMSE: 4.55
# Analysis: The MAE for Actual Condition shows a moderate level of deviation from actual values, which could reflect the model's performance in classifying weather conditions. The RMSE being slightly higher indicates that some predictions may be further off than the average error, pointing to the need for refining the model to improve classification accuracy.
# Occurrence of Flood
#
# MAE: 0.02
# RMSE: 0.02
# Analysis: Both MAE and RMSE for the Occurrence of Flood are extremely low, suggesting that the ARIMA model is highly effective at predicting whether a flood will occur. This level of accuracy is critical for early warning systems and disaster preparedness, demonstrating the model's reliability in this context.
# Insights and Recommendations
# Temperature Predictions: Given the relatively higher errors in temperature forecasting, consider revising the model parameters or incorporating additional explanatory variables (such as humidity and wind speed) to enhance prediction accuracy.
#
# Rainfall and Flood Predictions: The low error metrics for rainfall and flood occurrence are promising. Continuously monitoring the model's performance and making adjustments as more data becomes available will help maintain accuracy.
#
# Further Validation: It is recommended to conduct further validation of the model using cross-validation techniques and testing it on unseen data. This will help confirm the reliability of the forecasts and assess the model's generalization capabilities.
#
# Model Enhancement: Explore the integration of seasonal adjustments and external regressors to potentially improve the model's ability to capture more complex patterns in the data, particularly for temperature and actual condition forecasts.
#
# Conclusion
# The ARIMA model has demonstrated satisfactory performance in forecasting rainfall and the occurrence of floods,
# with very low errors indicating high reliability. While temperature predictions showed some room for improvement,
# the overall results are encouraging for applications in weather forecasting.
# By continually refining the model and validating its performance, it can become an essential tool for stakeholders in meteorology, agriculture, and disaster management.
