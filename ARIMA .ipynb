# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
from math import sqrt

# Load dataset
data = pd.read_csv('Cleaned_MCS_TEAM_DATAX.csv')

# Convert 'DATETIME' to datetime object
data['DATETIME'] = pd.to_datetime(data['DATETIME'])

# Sort dataset by date
data = data.sort_values(by='DATETIME')
print(data.columns)

# Encode categorical variables
le_condition = LabelEncoder()
le_flood = LabelEncoder()
data['ACTUAL CONDITION'] = le_condition.fit_transform(data['ACTUAL CONDITION'])
data['OCCURENCE OF FLOOD'] = le_flood.fit_transform(data['OCCURENCE OF FLOOD'])

# Set DATETIME as index
data.set_index('DATETIME', inplace=True)

# Resample to hourly data (assuming original data is at an interval of every 8 hours)
data = data.resample('h').mean().interpolate()  # Interpolating to fill gaps

# Features to forecast
features = ['TEMPERATURE (°C)', 'RAINFALL (mm)', 'ACTUAL CONDITION', 'OCCURENCE OF FLOOD']

# Function to fit SARIMA model and make forecasts
def fit_sarima(data, feature, order, seasonal_order, steps):
    model = SARIMAX(data[feature], order=order, seasonal_order=seasonal_order)
    results = model.fit(disp=True)
    forecast = results.forecast(steps)
    return forecast

# Parameters for SARIMA model (p, d, q) and seasonal parameters (P, D, Q, S)
p, d, q = 1, 1, 1  # Example parameters for non-seasonal part
P, D, Q, S = 1, 1, 1, 24  # Example parameters for seasonal part (e.g., daily seasonality)

# Number of steps to forecast (e.g., 168 hours for 7 days)
n_future = 168  # 7 days of hourly data

# Cross-validation setup using TimeSeriesSplit
tscv = TimeSeriesSplit(n_splits=5)

# Store results
cv_results = []

for feature in features:
    feature_cv_results = []
    for train_idx, test_idx in tscv.split(data):
        # Split the data into training and testing sets for each fold
        train_data = data.iloc[train_idx]
        test_data = data.iloc[test_idx]
        
        # Fit SARIMA model on training data and forecast on the test set
        forecast = fit_sarima(train_data, feature, (p, d, q), (P, D, Q, S), len(test_data))
        
        # Calculate the RMSE of the forecast
        rmse = sqrt(mean_squared_error(test_data[feature], forecast))
        feature_cv_results.append(rmse)
    
    # Append the results for each feature
    cv_results.append(np.mean(feature_cv_results))

# Print cross-validation results for each feature
for i, feature in enumerate(features):
    print(f'Cross-validation RMSE for {feature}: {cv_results[i]}')

# Forecast the next 7 days (7 * 24 = 168 hours) for each feature
forecasts = {}
for feature in features:
    forecasts[feature] = fit_sarima(data, feature, (p, d, q), (P, D, Q, S), n_future)

# Create a DataFrame for the forecasted data
forecast_dates = pd.date_range(start=data.index.max() + pd.Timedelta(hours=8), periods=n_future, freq='8H')
forecast_df = pd.DataFrame(forecasts, index=forecast_dates)
forecast_df.to_csv('ARIMA_forecast_results.csv', index=True)

# Plotting the forecast results
plt.figure(figsize=(14, 10))
for feature in features:
    plt.subplot(2, 2, features.index(feature) + 1)
    plt.plot(data[feature], label='Historical', color='blue')
    plt.plot(forecast_df[feature], label='Forecast', color='orange')
    plt.title(f'Forecast for {feature}')
    plt.xlabel('Date')
    plt.ylabel(feature)
    plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Index(['DATETIME', 'TEMPERATURE (°C)', 'RAINFALL (mm)', 'ACTUAL CONDITION',
#        'OCCURENCE OF FLOOD'],
#       dtype='object')
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.58938D-01    |proj g|=  7.66785D-01
#
# At iterate    1    f=  4.16596D-01    |proj g|=  1.33153D-01
#
# At iterate    2    f=  4.12817D-01    |proj g|=  1.67932D-01
#
# At iterate    3    f=  3.88301D-01    |proj g|=  3.41132D-01
#
# At iterate    4    f=  3.69883D-01    |proj g|=  7.40389D-01
#
# At iterate    5    f=  3.36691D-01    |proj g|=  8.80508D-02
#
# At iterate    6    f=  3.33369D-01    |proj g|=  1.12763D-01
#
# At iterate    7    f=  3.13768D-01    |proj g|=  4.90971D-02
#
# At iterate    8    f=  3.08743D-01    |proj g|=  4.30817D-02
#
# At iterate    9    f=  3.06177D-01    |proj g|=  6.39875D-02
#
# At iterate   10    f=  3.05398D-01    |proj g|=  3.59898D-02
#
# At iterate   11    f=  3.05162D-01    |proj g|=  6.41524D-03
#
# At iterate   12    f=  3.05135D-01    |proj g|=  1.89421D-03
#
# At iterate   13    f=  3.05131D-01    |proj g|=  1.71333D-03
#
# At iterate   14    f=  3.05129D-01    |proj g|=  3.35859D-03
#
# At iterate   15    f=  3.05126D-01    |proj g|=  1.36427D-03
#
# At iterate   16    f=  3.05120D-01    |proj g|=  6.68124D-04
#
# At iterate   17    f=  3.05119D-01    |proj g|=  3.13743D-03
#
# At iterate   18    f=  3.05118D-01    |proj g|=  9.36164D-04
#
# At iterate   19    f=  3.05118D-01    |proj g|=  6.76553D-05
#
# At iterate   20    f=  3.05118D-01    |proj g|=  2.97557D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     20     28      1     0     0   2.976D-06   3.051D-01
#   F =  0.30511837416140625
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.35470D-01    |proj g|=  6.93425D-01
#
# At iterate    1    f=  4.78041D-01    |proj g|=  2.34464D-01
#
# At iterate    2    f=  4.75090D-01    |proj g|=  2.63424D-01
#
# At iterate    3    f=  4.63713D-01    |proj g|=  1.23497D-01
#
# At iterate    4    f=  4.26271D-01    |proj g|=  2.41313D-01
#
# At iterate    5    f=  4.11170D-01    |proj g|=  1.36953D-01
#
# At iterate    6    f=  3.91966D-01    |proj g|=  8.59270D-02
#
# At iterate    7    f=  3.77932D-01    |proj g|=  6.66580D-02
#
# At iterate    8    f=  3.74297D-01    |proj g|=  9.87417D-02
#
# At iterate    9    f=  3.71322D-01    |proj g|=  1.73745D-02
#
# At iterate   10    f=  3.70449D-01    |proj g|=  4.32909D-03
#
# At iterate   11    f=  3.70281D-01    |proj g|=  1.05792D-02
#
# At iterate   12    f=  3.70205D-01    |proj g|=  4.55251D-03
#
# At iterate   13    f=  3.70203D-01    |proj g|=  3.25737D-03
#
# At iterate   14    f=  3.70203D-01    |proj g|=  2.81876D-04
#
# At iterate   15    f=  3.70203D-01    |proj g|=  2.61616D-04
#
# At iterate   16    f=  3.70202D-01    |proj g|=  3.22903D-04
#
# At iterate   17    f=  3.70202D-01    |proj g|=  1.19135D-04
#
# At iterate   18    f=  3.70202D-01    |proj g|=  3.16612D-05
#
# At iterate   19    f=  3.70202D-01    |proj g|=  7.68213D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     19     26      1     0     0   7.682D-06   3.702D-01
#   F =  0.37020228846049907
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.85041D-01    |proj g|=  5.43622D-01
#
# At iterate    1    f=  6.35609D-01    |proj g|=  3.60641D-01
#
# At iterate    2    f=  6.27709D-01    |proj g|=  1.88689D-01
#
# At iterate    3    f=  6.03378D-01    |proj g|=  1.02433D-01
#
# At iterate    4    f=  5.58981D-01    |proj g|=  2.68899D-01
#
# At iterate    5    f=  5.49958D-01    |proj g|=  7.16283D-02
#
# At iterate    6    f=  5.43481D-01    |proj g|=  7.06838D-02
#
# At iterate    7    f=  5.38308D-01    |proj g|=  8.26837D-02
#
# At iterate    8    f=  5.33194D-01    |proj g|=  1.80360D-02
#
# At iterate    9    f=  5.31587D-01    |proj g|=  3.09509D-02
#
# At iterate   10    f=  5.31043D-01    |proj g|=  2.13686D-02
#
# At iterate   11    f=  5.30932D-01    |proj g|=  5.90148D-03
#
# At iterate   12    f=  5.30914D-01    |proj g|=  4.43838D-03
#
# At iterate   13    f=  5.30913D-01    |proj g|=  8.34651D-04
#
# At iterate   14    f=  5.30912D-01    |proj g|=  7.37542D-04
#
# At iterate   15    f=  5.30911D-01    |proj g|=  5.03877D-04
#
# At iterate   16    f=  5.30911D-01    |proj g|=  1.03341D-04
#
# At iterate   17    f=  5.30911D-01    |proj g|=  2.17928D-05
#
# At iterate   18    f=  5.30911D-01    |proj g|=  6.13531D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     18     22      1     0     0   6.135D-07   5.309D-01
#   F =  0.53091083982248766
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.35896D-01    |proj g|=  4.86140D-01
#  This problem is unconstrained.
# At iterate    1    f=  6.80680D-01    |proj g|=  1.21167D-01
#
# At iterate    2    f=  6.55584D-01    |proj g|=  3.72199D-01
#
# At iterate    3    f=  6.18101D-01    |proj g|=  1.66747D-01
#
# At iterate    4    f=  6.03408D-01    |proj g|=  2.65198D-01
#
# At iterate    5    f=  5.96340D-01    |proj g|=  1.05717D-01
#
# At iterate    6    f=  5.87350D-01    |proj g|=  7.45153D-02
#
# At iterate    7    f=  5.80059D-01    |proj g|=  5.45780D-02
#
# At iterate    8    f=  5.76735D-01    |proj g|=  2.05365D-02
#
# At iterate    9    f=  5.75220D-01    |proj g|=  1.77953D-02
#
# At iterate   10    f=  5.75014D-01    |proj g|=  1.00109D-02
#
# At iterate   11    f=  5.74972D-01    |proj g|=  2.04813D-03
#
# At iterate   12    f=  5.74971D-01    |proj g|=  4.16457D-04
#
# At iterate   13    f=  5.74970D-01    |proj g|=  6.09865D-04
#
# At iterate   14    f=  5.74970D-01    |proj g|=  8.75033D-04
#
# At iterate   15    f=  5.74970D-01    |proj g|=  2.27594D-04
#
# At iterate   16    f=  5.74970D-01    |proj g|=  1.40090D-04
#
# At iterate   17    f=  5.74970D-01    |proj g|=  1.59015D-05
#
# At iterate   18    f=  5.74970D-01    |proj g|=  9.96269D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     18     25      1     0     0   9.963D-06   5.750D-01
#   F =  0.57496975010116214
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.11094D-01    |proj g|=  5.02277D-01
#  This problem is unconstrained.
# At iterate    1    f=  6.66581D-01    |proj g|=  3.72239D-01
#
# At iterate    2    f=  6.55059D-01    |proj g|=  1.20217D-01
#
# At iterate    3    f=  6.36467D-01    |proj g|=  3.54788D-01
#
# At iterate    4    f=  6.04872D-01    |proj g|=  5.61345D-01
#
# At iterate    5    f=  5.78435D-01    |proj g|=  9.79116D-02
#
# At iterate    6    f=  5.68076D-01    |proj g|=  7.33327D-02
#
# At iterate    7    f=  5.59762D-01    |proj g|=  1.05107D-01
#
# At iterate    8    f=  5.53217D-01    |proj g|=  1.53754D-02
#
# At iterate    9    f=  5.51237D-01    |proj g|=  4.28836D-02
#
# At iterate   10    f=  5.50458D-01    |proj g|=  3.69848D-02
#
# At iterate   11    f=  5.50435D-01    |proj g|=  4.56320D-02
#
# At iterate   12    f=  5.50167D-01    |proj g|=  5.32067D-03
#
# At iterate   13    f=  5.50159D-01    |proj g|=  6.94285D-04
#
# At iterate   14    f=  5.50158D-01    |proj g|=  5.12130D-04
#
# At iterate   15    f=  5.50158D-01    |proj g|=  2.32641D-04
#
# At iterate   16    f=  5.50158D-01    |proj g|=  1.62679D-04
#
# At iterate   17    f=  5.50158D-01    |proj g|=  5.04153D-05
#
# At iterate   18    f=  5.50158D-01    |proj g|=  3.45885D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     18     27      1     0     0   3.459D-05   5.502D-01
#   F =  0.55015801433230105
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.76686D-01    |proj g|=  5.13690D-01
#
# At iterate    1    f=  7.45542D-01    |proj g|=  2.20078D-01
#
# At iterate    2    f=  7.38297D-01    |proj g|=  2.81545D-01
#
# At iterate    3    f=  7.32389D-01    |proj g|=  1.22735D-01
#
# At iterate    4    f=  7.21155D-01    |proj g|=  1.13287D-01
#
# At iterate    5    f=  6.80601D-01    |proj g|=  3.51867D-01
#
# At iterate    6    f=  6.62501D-01    |proj g|=  3.03436D-01
#
# At iterate    7    f=  6.21994D-01    |proj g|=  1.41475D-01
#
# At iterate    8    f=  6.05498D-01    |proj g|=  1.30748D-01
#
# At iterate    9    f=  6.01177D-01    |proj g|=  1.53887D-01
#
# At iterate   10    f=  5.93955D-01    |proj g|=  3.16007D-02
#
# At iterate   11    f=  5.91222D-01    |proj g|=  1.32833D-02
#
# At iterate   12    f=  5.89640D-01    |proj g|=  5.12643D-03
#
# At iterate   13    f=  5.88846D-01    |proj g|=  6.53818D-03
#
# At iterate   14    f=  5.88675D-01    |proj g|=  1.09228D-02
#
# At iterate   15    f=  5.88312D-01    |proj g|=  3.94189D-03
#
# At iterate   16    f=  5.88079D-01    |proj g|=  1.64592D-02
#
# At iterate   17    f=  5.87938D-01    |proj g|=  4.93429D-03
#
# At iterate   18    f=  5.87862D-01    |proj g|=  1.98439D-03
#
# At iterate   19    f=  5.87810D-01    |proj g|=  5.09148D-03
#
# At iterate   20    f=  5.87773D-01    |proj g|=  3.80304D-03
#
# At iterate   21    f=  5.87760D-01    |proj g|=  1.38992D-03
#
# At iterate   22    f=  5.87752D-01    |proj g|=  1.03791D-03
#
# At iterate   23    f=  5.87742D-01    |proj g|=  4.91943D-04
#
# At iterate   24    f=  5.87739D-01    |proj g|=  5.28252D-03
#
# At iterate   25    f=  5.87735D-01    |proj g|=  1.18893D-03
#
# At iterate   26    f=  5.87732D-01    |proj g|=  1.15741D-03
#
# At iterate   27    f=  5.87730D-01    |proj g|=  9.05942D-04
#
# At iterate   28    f=  5.87730D-01    |proj g|=  8.20646D-04
#
# At iterate   29    f=  5.87729D-01    |proj g|=  8.68594D-04
#
# At iterate   30    f=  5.87729D-01    |proj g|=  7.30480D-04
#
# At iterate   31    f=  5.87729D-01    |proj g|=  3.45229D-04
#
# At iterate   32    f=  5.87729D-01    |proj g|=  3.99422D-04
#
# At iterate   33    f=  5.87729D-01    |proj g|=  5.11215D-04
#
# At iterate   34    f=  5.87729D-01    |proj g|=  4.38792D-04
#
# At iterate   35    f=  5.87729D-01    |proj g|=  1.63263D-04
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# At iterate   36    f=  5.87729D-01    |proj g|=  3.76294D-05
#
# At iterate   37    f=  5.87729D-01    |proj g|=  3.00850D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     37     64      2     0     0   3.009D-05   5.877D-01
#   F =  0.58772854583753964
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.08721D+00    |proj g|=  3.21727D-01
#  This problem is unconstrained.
# At iterate    1    f=  1.06322D+00    |proj g|=  1.07597D-01
#
# At iterate    2    f=  1.05207D+00    |proj g|=  1.70554D-01
#
# At iterate    3    f=  1.00261D+00    |proj g|=  3.63906D-01
#
# At iterate    4    f=  9.63614D-01    |proj g|=  1.77858D-01
#
# At iterate    5    f=  9.42092D-01    |proj g|=  9.30331D-02
#
# At iterate    6    f=  9.24944D-01    |proj g|=  5.84457D-02
#
# At iterate    7    f=  9.13738D-01    |proj g|=  4.64031D-02
#
# At iterate    8    f=  9.09320D-01    |proj g|=  4.63631D-02
#
# At iterate    9    f=  9.08648D-01    |proj g|=  3.73415D-02
#
# At iterate   10    f=  9.06468D-01    |proj g|=  7.42894D-03
#
# At iterate   11    f=  9.05600D-01    |proj g|=  4.71198D-03
#
# At iterate   12    f=  9.05491D-01    |proj g|=  8.72543D-03
#
# At iterate   13    f=  9.05385D-01    |proj g|=  1.32852D-03
#
# At iterate   14    f=  9.05376D-01    |proj g|=  4.87595D-05
#
# At iterate   15    f=  9.05376D-01    |proj g|=  1.79337D-05
#
# At iterate   16    f=  9.05376D-01    |proj g|=  1.66292D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     16     24      1     0     0   1.663D-05   9.054D-01
#   F =  0.90537595663177650
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.13393D+00    |proj g|=  2.63310D-01
#
# At iterate    1    f=  1.11491D+00    |proj g|=  9.90850D-02
#
# At iterate    2    f=  1.10573D+00    |proj g|=  1.18970D-01
#
# At iterate    3    f=  1.08303D+00    |proj g|=  3.60016D-01
#
# At iterate    4    f=  1.05829D+00    |proj g|=  4.50990D-01
#
# At iterate    5    f=  1.02063D+00    |proj g|=  1.70716D-01
#
# At iterate    6    f=  9.96302D-01    |proj g|=  5.99140D-02
#
# At iterate    7    f=  9.81169D-01    |proj g|=  3.06979D-02
#
# At iterate    8    f=  9.71851D-01    |proj g|=  6.63226D-02
#
# At iterate    9    f=  9.66322D-01    |proj g|=  9.32198D-03
#
# At iterate   10    f=  9.63433D-01    |proj g|=  4.36662D-03
#
# At iterate   11    f=  9.62888D-01    |proj g|=  2.41733D-02
#
# At iterate   12    f=  9.61447D-01    |proj g|=  9.05359D-03
#
# At iterate   13    f=  9.60732D-01    |proj g|=  1.21821D-03
#
# At iterate   14    f=  9.60544D-01    |proj g|=  4.11967D-03
#
# At iterate   15    f=  9.60532D-01    |proj g|=  5.78393D-03
#
# At iterate   16    f=  9.60503D-01    |proj g|=  9.56668D-04
#
# At iterate   17    f=  9.60501D-01    |proj g|=  1.76741D-04
#
# At iterate   18    f=  9.60500D-01    |proj g|=  1.41347D-04
#
# At iterate   19    f=  9.60500D-01    |proj g|=  7.14926D-05
#
# At iterate   20    f=  9.60500D-01    |proj g|=  2.74658D-05
#
# At iterate   21    f=  9.60500D-01    |proj g|=  1.49885D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     21     28      1     0     0   1.499D-06   9.605D-01
#   F =  0.96050043526312012
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.18833D+00    |proj g|=  2.60836D-01
#  This problem is unconstrained.
# At iterate    1    f=  1.16721D+00    |proj g|=  9.24585D-02
#
# At iterate    2    f=  1.15601D+00    |proj g|=  1.29548D-01
#
# At iterate    3    f=  1.13668D+00    |proj g|=  2.72834D-01
#
# At iterate    4    f=  1.11263D+00    |proj g|=  3.58514D-01
#
# At iterate    5    f=  1.07997D+00    |proj g|=  1.28949D-01
#
# At iterate    6    f=  1.05285D+00    |proj g|=  5.18122D-02
#
# At iterate    7    f=  1.03646D+00    |proj g|=  2.64406D-02
#
# At iterate    8    f=  1.02708D+00    |proj g|=  6.86480D-02
#
# At iterate    9    f=  1.02033D+00    |proj g|=  1.00294D-02
#
# At iterate   10    f=  1.01763D+00    |proj g|=  2.59508D-02
#
# At iterate   11    f=  1.01560D+00    |proj g|=  1.06702D-02
#
# At iterate   12    f=  1.01455D+00    |proj g|=  6.90558D-03
#
# At iterate   13    f=  1.01407D+00    |proj g|=  3.98678D-03
#
# At iterate   14    f=  1.01392D+00    |proj g|=  5.24887D-03
#
# At iterate   15    f=  1.01387D+00    |proj g|=  9.78710D-04
#
# At iterate   16    f=  1.01387D+00    |proj g|=  8.19506D-04
#
# At iterate   17    f=  1.01386D+00    |proj g|=  2.06981D-03
#
# At iterate   18    f=  1.01386D+00    |proj g|=  9.69678D-04
#
# At iterate   19    f=  1.01386D+00    |proj g|=  3.74159D-04
#
# At iterate   20    f=  1.01386D+00    |proj g|=  2.83290D-04
#
# At iterate   21    f=  1.01386D+00    |proj g|=  6.06182D-05
#
# At iterate   22    f=  1.01386D+00    |proj g|=  3.57719D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     22     27      1     0     0   3.577D-05   1.014D+00
#   F =   1.0138612246728484
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.16942D+00    |proj g|=  2.99276D-01
#
# At iterate    1    f=  1.14463D+00    |proj g|=  1.06650D-01
#
# At iterate    2    f=  1.13122D+00    |proj g|=  1.90463D-01
#
# At iterate    3    f=  1.08398D+00    |proj g|=  2.50877D-01
#
# At iterate    4    f=  1.04070D+00    |proj g|=  1.02496D-01
#
# At iterate    5    f=  1.02018D+00    |proj g|=  4.92056D-02
#
# At iterate    6    f=  1.00644D+00    |proj g|=  5.88073D-02
#
# At iterate    7    f=  9.97975D-01    |proj g|=  8.47362D-02
#
# At iterate    8    f=  9.93567D-01    |proj g|=  2.33028D-02
#
# At iterate    9    f=  9.91106D-01    |proj g|=  2.03521D-02
#
# At iterate   10    f=  9.89728D-01    |proj g|=  1.35749D-02
#
# At iterate   11    f=  9.88795D-01    |proj g|=  2.79970D-03
#
# At iterate   12    f=  9.88529D-01    |proj g|=  2.41279D-03
#
# At iterate   13    f=  9.88464D-01    |proj g|=  4.96880D-03
#
# At iterate   14    f=  9.88452D-01    |proj g|=  5.53984D-03
#
# At iterate   15    f=  9.88448D-01    |proj g|=  3.22148D-04
#
# At iterate   16    f=  9.88448D-01    |proj g|=  2.72394D-04
#
# At iterate   17    f=  9.88448D-01    |proj g|=  2.31888D-04
#
# At iterate   18    f=  9.88447D-01    |proj g|=  2.73274D-04
#
# At iterate   19    f=  9.88447D-01    |proj g|=  8.79467D-05
#
# At iterate   20    f=  9.88447D-01    |proj g|=  2.46868D-05
#
# At iterate   21    f=  9.88447D-01    |proj g|=  2.78638D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     21     27      1     0     0   2.786D-06   9.884D-01
#   F =  0.98844740289600397
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -7.04767D-02    |proj g|=  1.28277D+00
#  This problem is unconstrained.
# At iterate    1    f= -1.06113D-01    |proj g|=  6.46645D-01
#
# At iterate    2    f= -1.09301D-01    |proj g|=  3.13290D-01
#
# At iterate    3    f= -1.10932D-01    |proj g|=  1.05999D-01
#
# At iterate    4    f= -1.11933D-01    |proj g|=  1.09747D-01
#
# At iterate    5    f= -1.14460D-01    |proj g|=  3.09153D-01
#
# At iterate    6    f= -1.21396D-01    |proj g|=  7.42024D-01
#
# At iterate    7    f= -1.35159D-01    |proj g|=  1.28985D+00
#
# At iterate    8    f= -1.52903D-01    |proj g|=  1.27994D+00
#
# At iterate    9    f= -1.84701D-01    |proj g|=  7.46194D-01
#
# At iterate   10    f= -2.09715D-01    |proj g|=  6.81694D-02
#
# At iterate   11    f= -2.18743D-01    |proj g|=  9.38329D-02
#
# At iterate   12    f= -2.25090D-01    |proj g|=  1.69816D-01
#
# At iterate   13    f= -2.33424D-01    |proj g|=  1.51326D-01
#
# At iterate   14    f= -2.38857D-01    |proj g|=  7.91907D-02
#
# At iterate   15    f= -2.40005D-01    |proj g|=  6.24152D-02
#
# At iterate   16    f= -2.41979D-01    |proj g|=  2.12486D-01
#
# At iterate   17    f= -2.42936D-01    |proj g|=  1.13473D-01
#
# At iterate   18    f= -2.43348D-01    |proj g|=  3.35122D-02
#
# At iterate   19    f= -2.43604D-01    |proj g|=  1.54308D-02
#
# At iterate   20    f= -2.43775D-01    |proj g|=  2.51112D-02
#
# At iterate   21    f= -2.44094D-01    |proj g|=  2.90582D-02
#
# At iterate   22    f= -2.44177D-01    |proj g|=  2.85556D-02
#
# At iterate   23    f= -2.44450D-01    |proj g|=  1.08447D-02
#
# At iterate   24    f= -2.44514D-01    |proj g|=  1.56540D-03
#
# At iterate   25    f= -2.44517D-01    |proj g|=  2.24000D-03
#
# At iterate   26    f= -2.44518D-01    |proj g|=  8.69752D-04
#
# At iterate   27    f= -2.44519D-01    |proj g|=  9.82276D-04
#
# At iterate   28    f= -2.44521D-01    |proj g|=  9.16711D-03
#
# At iterate   29    f= -2.44527D-01    |proj g|=  1.01371D-02
#
# At iterate   30    f= -2.44536D-01    |proj g|=  7.79900D-04
#
# At iterate   31    f= -2.44542D-01    |proj g|=  8.03904D-03
#
# At iterate   32    f= -2.44543D-01    |proj g|=  1.38902D-02
#
# At iterate   33    f= -2.44546D-01    |proj g|=  3.67636D-03
#
# At iterate   34    f= -2.44550D-01    |proj g|=  6.85956D-04
#
# At iterate   35    f= -2.44551D-01    |proj g|=  1.52096D-03
#
# At iterate   36    f= -2.44551D-01    |proj g|=  5.89714D-04
#
# At iterate   37    f= -2.44552D-01    |proj g|=  3.72019D-04
#
# At iterate   38    f= -2.44552D-01    |proj g|=  1.19780D-03
#
# At iterate   39    f= -2.44552D-01    |proj g|=  3.08857D-03
#
# At iterate   40    f= -2.44552D-01    |proj g|=  3.09513D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     40     66      1     0     0   3.095D-03  -2.446D-01
#   F = -0.24455231915931372
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.72214D-01    |proj g|=  9.65771D-01
#
# At iterate    1    f=  1.46519D-01    |proj g|=  8.51610D-01
#
# At iterate    2    f=  1.38559D-01    |proj g|=  3.28937D-01
#
# At iterate    3    f=  1.35707D-01    |proj g|=  9.88763D-02
#
# At iterate    4    f=  1.34383D-01    |proj g|=  1.04313D-01
#
# At iterate    5    f=  1.32192D-01    |proj g|=  2.19031D-01
#
# At iterate    6    f=  1.23200D-01    |proj g|=  6.63581D-01
#
# At iterate    7    f=  1.07441D-01    |proj g|=  1.25183D+00
#
# At iterate    8    f=  8.68838D-02    |proj g|=  1.26009D+00
#
# At iterate    9    f=  4.69137D-02    |proj g|=  6.48787D-01
#
# At iterate   10    f=  1.67794D-02    |proj g|=  5.92688D-02
#
# At iterate   11    f=  3.51573D-03    |proj g|=  1.36042D-01
#
# At iterate   12    f= -5.94013D-03    |proj g|=  1.32080D-01
#
# At iterate   13    f= -8.25938D-03    |proj g|=  4.64023D-02
#
# At iterate   14    f= -1.20286D-02    |proj g|=  2.73670D-02
#
# At iterate   15    f= -1.40625D-02    |proj g|=  7.50213D-02
#
# At iterate   16    f= -1.49427D-02    |proj g|=  9.53293D-03
#
# At iterate   17    f= -1.52292D-02    |proj g|=  1.79274D-02
#
# At iterate   18    f= -1.52432D-02    |proj g|=  1.21512D-02
#
# At iterate   19    f= -1.52667D-02    |proj g|=  7.47265D-03
#
# At iterate   20    f= -1.52780D-02    |proj g|=  8.48155D-03
#
# At iterate   21    f= -1.53030D-02    |proj g|=  3.42876D-03
#
# At iterate   22    f= -1.53172D-02    |proj g|=  3.05306D-03
#
# At iterate   23    f= -1.53421D-02    |proj g|=  3.83655D-03
#
# At iterate   24    f= -1.53501D-02    |proj g|=  2.69341D-03
#
# At iterate   25    f= -1.53514D-02    |proj g|=  7.91810D-04
#
# At iterate   26    f= -1.53516D-02    |proj g|=  1.42780D-04
#
# At iterate   27    f= -1.53516D-02    |proj g|=  4.39435D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     27     33      1     0     0   4.394D-06  -1.535D-02
#   F =  -1.5351631272903812E-002
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.13093D-01    |proj g|=  9.01332D-01
#  This problem is unconstrained.
# At iterate    1    f=  1.83408D-01    |proj g|=  3.52053D-01
#
# At iterate    2    f=  1.79870D-01    |proj g|=  3.36785D-01
#
# At iterate    3    f=  1.77434D-01    |proj g|=  1.19586D-01
#
# At iterate    4    f=  1.69738D-01    |proj g|=  2.77239D-01
#
# At iterate    5    f=  1.51552D-01    |proj g|=  5.59452D-01
#
# At iterate    6    f=  1.20576D-01    |proj g|=  7.41013D-01
#
# At iterate    7    f=  9.46221D-02    |proj g|=  6.55648D-01
#
# At iterate    8    f=  5.14102D-02    |proj g|=  1.02722D+00
#
# At iterate    9    f=  4.30705D-02    |proj g|=  1.40626D-01
#
# At iterate   10    f=  3.91870D-02    |proj g|=  1.34695D-01
#
# At iterate   11    f=  2.92514D-02    |proj g|=  1.91589D-01
#
# At iterate   12    f=  2.29952D-02    |proj g|=  8.33188D-02
#
# At iterate   13    f=  2.10285D-02    |proj g|=  1.46608D-02
#
# At iterate   14    f=  1.92302D-02    |proj g|=  9.28418D-03
#
# At iterate   15    f=  1.88397D-02    |proj g|=  1.02604D-01
#
# At iterate   16    f=  1.84818D-02    |proj g|=  1.87703D-02
#
# At iterate   17    f=  1.84447D-02    |proj g|=  6.56836D-03
#
# At iterate   18    f=  1.84379D-02    |proj g|=  7.48902D-03
#
# At iterate   19    f=  1.84279D-02    |proj g|=  4.04244D-03
#
# At iterate   20    f=  1.84277D-02    |proj g|=  2.25091D-03
#
# At iterate   21    f=  1.84270D-02    |proj g|=  2.10059D-04
#
# At iterate   22    f=  1.84269D-02    |proj g|=  1.54072D-04
#
# At iterate   23    f=  1.84269D-02    |proj g|=  4.28274D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     23     29      1     0     0   4.283D-06   1.843D-02
#   F =   1.8426934555928476E-002
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.46667D-01    |proj g|=  8.32844D-01
#  This problem is unconstrained.
# At iterate    1    f=  2.21371D-01    |proj g|=  3.66590D-01
#
# At iterate    2    f=  2.17314D-01    |proj g|=  3.29596D-01
#
# At iterate    3    f=  2.14866D-01    |proj g|=  1.09101D-01
#
# At iterate    4    f=  2.07689D-01    |proj g|=  2.13584D-01
#
# At iterate    5    f=  1.84756D-01    |proj g|=  5.57595D-01
#
# At iterate    6    f=  1.62732D-01    |proj g|=  6.15587D-01
#
# At iterate    7    f=  1.32126D-01    |proj g|=  6.16812D-01
#
# At iterate    8    f=  1.11574D-01    |proj g|=  1.17711D+00
#
# At iterate    9    f=  8.96397D-02    |proj g|=  1.04036D-01
#
# At iterate   10    f=  8.30828D-02    |proj g|=  3.54626D-02
#
# At iterate   11    f=  7.45232D-02    |proj g|=  2.04893D-01
#
# At iterate   12    f=  7.19210D-02    |proj g|=  1.64260D-01
#
# At iterate   13    f=  6.87782D-02    |proj g|=  5.55869D-02
#
# At iterate   14    f=  6.68901D-02    |proj g|=  8.19630D-03
#
# At iterate   15    f=  6.60261D-02    |proj g|=  9.56591D-03
#
# At iterate   16    f=  6.57897D-02    |proj g|=  2.09218D-02
#
# At iterate   17    f=  6.52900D-02    |proj g|=  6.81069D-03
#
# At iterate   18    f=  6.51374D-02    |proj g|=  2.65852D-03
#
# At iterate   19    f=  6.50658D-02    |proj g|=  4.34978D-03
#
# At iterate   20    f=  6.50648D-02    |proj g|=  2.75532D-03
#
# At iterate   21    f=  6.50512D-02    |proj g|=  4.69406D-04
#
# At iterate   22    f=  6.50493D-02    |proj g|=  1.08106D-04
#
# At iterate   23    f=  6.50493D-02    |proj g|=  2.57214D-04
#
# At iterate   24    f=  6.50493D-02    |proj g|=  9.04767D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     24     32      1     0     0   9.048D-06   6.505D-02
#   F =   6.5049273712312422E-002
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.36198D-01    |proj g|=  8.70676D-01
#  This problem is unconstrained.
# At iterate    1    f=  2.08124D-01    |proj g|=  3.65136D-01
#
# At iterate    2    f=  2.04536D-01    |proj g|=  3.40377D-01
#
# At iterate    3    f=  2.02100D-01    |proj g|=  1.06365D-01
#
# At iterate    4    f=  1.95901D-01    |proj g|=  1.56556D-01
#
# At iterate    5    f=  1.65302D-01    |proj g|=  5.96187D-01
#
# At iterate    6    f=  1.47942D-01    |proj g|=  5.67394D-01
#
# At iterate    7    f=  1.15970D-01    |proj g|=  5.40733D-01
#
# At iterate    8    f=  9.02281D-02    |proj g|=  6.49187D-01
#
# At iterate    9    f=  8.03832D-02    |proj g|=  4.32023D-02
#
# At iterate   10    f=  7.35116D-02    |proj g|=  6.42943D-02
#
# At iterate   11    f=  6.52901D-02    |proj g|=  1.50968D-02
#
# At iterate   12    f=  6.10843D-02    |proj g|=  6.97304D-02
#
# At iterate   13    f=  5.88251D-02    |proj g|=  1.82480D-02
#
# At iterate   14    f=  5.78210D-02    |proj g|=  3.58609D-02
#
# At iterate   15    f=  5.72817D-02    |proj g|=  5.40493D-03
#
# At iterate   16    f=  5.70703D-02    |proj g|=  6.36919D-03
#
# At iterate   17    f=  5.69892D-02    |proj g|=  6.79303D-03
#
# At iterate   18    f=  5.69762D-02    |proj g|=  1.31256D-03
#
# At iterate   19    f=  5.69727D-02    |proj g|=  1.08328D-03
#
# At iterate   20    f=  5.69722D-02    |proj g|=  3.41167D-03
#
# At iterate   21    f=  5.69710D-02    |proj g|=  1.55467D-03
#
# At iterate   22    f=  5.69684D-02    |proj g|=  1.27575D-03
#
# At iterate   23    f=  5.69669D-02    |proj g|=  1.75907D-03
#
# At iterate   24    f=  5.69667D-02    |proj g|=  3.27593D-04
#
# At iterate   25    f=  5.69664D-02    |proj g|=  1.34440D-04
#
# At iterate   26    f=  5.69663D-02    |proj g|=  9.73260D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     26     34      1     0     0   9.733D-06   5.697D-02
#   F =   5.6966349434732701E-002
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.48271D+00    |proj g|=  1.35898D+01
#
# At iterate    1    f= -2.50619D+00    |proj g|=  1.08179D+01
#
# At iterate    2    f= -2.51231D+00    |proj g|=  4.28934D+00
#
# At iterate    3    f= -2.51417D+00    |proj g|=  9.49139D-01
#
# At iterate    4    f= -2.51425D+00    |proj g|=  1.21659D-01
#
# At iterate    5    f= -2.51426D+00    |proj g|=  9.92549D-02
#
# At iterate    6    f= -2.51427D+00    |proj g|=  1.71801D-01
#
# At iterate    7    f= -2.51431D+00    |proj g|=  4.66224D-01
#
# At iterate    8    f= -2.51440D+00    |proj g|=  9.28347D-01
#
# At iterate    9    f= -2.51465D+00    |proj g|=  1.72034D+00
#
# At iterate   10    f= -2.51523D+00    |proj g|=  2.80810D+00
#
# At iterate   11    f= -2.51688D+00    |proj g|=  4.68707D+00
#
# At iterate   12    f= -2.52077D+00    |proj g|=  7.36664D+00
#
# At iterate   13    f= -2.52921D+00    |proj g|=  1.05914D+01
#
# At iterate   14    f= -2.54344D+00    |proj g|=  1.33194D+01
#
# At iterate   15    f= -2.55620D+00    |proj g|=  1.19446D+01
#
# At iterate   16    f= -2.57162D+00    |proj g|=  2.75264D+00
#
# At iterate   17    f= -2.57486D+00    |proj g|=  5.14925D-01
#
# At iterate   18    f= -2.57494D+00    |proj g|=  1.50886D-01
#
# At iterate   19    f= -2.57497D+00    |proj g|=  1.39782D-01
#
# At iterate   20    f= -2.57506D+00    |proj g|=  3.94793D-01
#
# At iterate   21    f= -2.57525D+00    |proj g|=  8.76098D-01
#
# At iterate   22    f= -2.57590D+00    |proj g|=  1.95349D+00
#
# At iterate   23    f= -2.57688D+00    |proj g|=  2.75393D+00
#
# At iterate   24    f= -2.58341D+00    |proj g|=  6.64415D+00
#
# At iterate   25    f= -2.59253D+00    |proj g|=  8.87435D+00
#
# At iterate   26    f= -2.61565D+00    |proj g|=  9.82298D+00
#
# At iterate   27    f= -2.63937D+00    |proj g|=  4.57644D-01
#
# At iterate   28    f= -2.65517D+00    |proj g|=  2.41309D+00
#
# At iterate   29    f= -2.65834D+00    |proj g|=  6.73151D-01
#
# At iterate   30    f= -2.65956D+00    |proj g|=  1.61379D+00
#
# At iterate   31    f= -2.65978D+00    |proj g|=  7.11350D-01
#
# At iterate   32    f= -2.65991D+00    |proj g|=  1.54038D-01
#
# At iterate   33    f= -2.65991D+00    |proj g|=  2.52446D-01
#
# At iterate   34    f= -2.65991D+00    |proj g|=  2.65006D-01
#
# At iterate   35    f= -2.66215D+00    |proj g|=  1.12679D+00
#
# At iterate   36    f= -2.66542D+00    |proj g|=  1.06768D+00
#
# At iterate   37    f= -2.66544D+00    |proj g|=  9.49352D-01
#
# At iterate   38    f= -2.66556D+00    |proj g|=  9.83591D-03
#
# At iterate   39    f= -2.66564D+00    |proj g|=  6.31991D-01
#
# At iterate   40    f= -2.66577D+00    |proj g|=  7.43220D-01
#
# At iterate   41    f= -2.66692D+00    |proj g|=  1.04836D+00
#
# At iterate   42    f= -2.66795D+00    |proj g|=  9.39839D-01
#
# At iterate   43    f= -2.66801D+00    |proj g|=  3.47169D-01
#
# At iterate   44    f= -2.66844D+00    |proj g|=  3.81122D-01
#
# At iterate   45    f= -2.66881D+00    |proj g|=  4.25519D-01
#
# At iterate   46    f= -2.66897D+00    |proj g|=  1.84238D-01
#
# At iterate   47    f= -2.66908D+00    |proj g|=  2.32183D-02
#
# At iterate   48    f= -2.66924D+00    |proj g|=  4.71789D-02
#
# At iterate   49    f= -2.66926D+00    |proj g|=  4.80158D-01
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# /Users/freshliannes.rosal/anaconda3/envs/Numerical/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# At iterate   50    f= -2.66927D+00    |proj g|=  9.83389D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     50     88      2     0     0   9.834D-02  -2.669D+00
#   F =  -2.6692721973313995
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.17100D+00    |proj g|=  1.02609D+01
#
# At iterate    1    f= -2.20610D+00    |proj g|=  1.47263D+00
#
# At iterate    2    f= -2.20631D+00    |proj g|=  1.06195D+00
#
# At iterate    3    f= -2.20651D+00    |proj g|=  1.16419D-01
#
# At iterate    4    f= -2.20654D+00    |proj g|=  1.18635D-01
#
# At iterate    5    f= -2.20675D+00    |proj g|=  6.97101D-01
#
# At iterate    6    f= -2.20725D+00    |proj g|=  1.54114D+00
#
# At iterate    7    f= -2.20865D+00    |proj g|=  3.06047D+00
#
# At iterate    8    f= -2.21226D+00    |proj g|=  5.58696D+00
#
# At iterate    9    f= -2.22158D+00    |proj g|=  1.00356D+01
#
# At iterate   10    f= -2.23967D+00    |proj g|=  1.53517D+01
#
# At iterate   11    f= -2.26261D+00    |proj g|=  1.26983D+01
#
# At iterate   12    f= -2.27966D+00    |proj g|=  2.74892D+00
#
# At iterate   13    f= -2.28085D+00    |proj g|=  6.79408D-01
#
# At iterate   14    f= -2.28095D+00    |proj g|=  1.44944D-01
#
# At iterate   15    f= -2.28096D+00    |proj g|=  1.44088D-01
#
# At iterate   16    f= -2.28103D+00    |proj g|=  4.51459D-01
#
# At iterate   17    f= -2.28117D+00    |proj g|=  8.74238D-01
#
# At iterate   18    f= -2.28158D+00    |proj g|=  1.61801D+00
#
# At iterate   19    f= -2.28253D+00    |proj g|=  2.62998D+00
#
# At iterate   20    f= -2.28494D+00    |proj g|=  4.10228D+00
#
# At iterate   21    f= -2.29033D+00    |proj g|=  5.90771D+00
#
# At iterate   22    f= -2.30090D+00    |proj g|=  7.34133D+00
#
# At iterate   23    f= -2.32108D+00    |proj g|=  7.58315D+00
#
# At iterate   24    f= -2.33812D+00    |proj g|=  5.08468D+00
#
# At iterate   25    f= -2.35640D+00    |proj g|=  1.18889D+00
#
# At iterate   26    f= -2.35767D+00    |proj g|=  2.17941D+00
#
# At iterate   27    f= -2.36006D+00    |proj g|=  1.80608D+00
#
# At iterate   28    f= -2.36197D+00    |proj g|=  4.07998D-01
#
# At iterate   29    f= -2.36234D+00    |proj g|=  5.00761D-02
#
# At iterate   30    f= -2.36243D+00    |proj g|=  8.50027D-02
#
# At iterate   31    f= -2.36260D+00    |proj g|=  3.72781D-01
#
# At iterate   32    f= -2.36301D+00    |proj g|=  1.27226D+00
#
# At iterate   33    f= -2.36385D+00    |proj g|=  1.50965D-01
#
# At iterate   34    f= -2.36420D+00    |proj g|=  4.39998D-01
#
# At iterate   35    f= -2.36420D+00    |proj g|=  1.33639D-01
#
# At iterate   36    f= -2.36423D+00    |proj g|=  1.38101D-01
#
# At iterate   37    f= -2.36428D+00    |proj g|=  3.39676D-01
#
# At iterate   38    f= -2.36432D+00    |proj g|=  2.38279D-01
#
# At iterate   39    f= -2.36433D+00    |proj g|=  2.20467D-01
#
# At iterate   40    f= -2.36433D+00    |proj g|=  2.74043D-02
#
# At iterate   41    f= -2.36433D+00    |proj g|=  3.13876D-02
#
# At iterate   42    f= -2.36434D+00    |proj g|=  4.85211D-02
#
# At iterate   43    f= -2.36434D+00    |proj g|=  5.12299D-02
#
# At iterate   44    f= -2.36434D+00    |proj g|=  2.49853D-02
#
# At iterate   45    f= -2.36434D+00    |proj g|=  7.52311D-03
#
# At iterate   46    f= -2.36436D+00    |proj g|=  2.89367D-01
#
# At iterate   47    f= -2.36438D+00    |proj g|=  1.36000D-01
#
# At iterate   48    f= -2.36440D+00    |proj g|=  8.34740D-02
#
# At iterate   49    f= -2.36440D+00    |proj g|=  6.50143D-03
# /Users/freshliannes.rosal/anaconda3/envs/Numerical/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# At iterate   50    f= -2.36447D+00    |proj g|=  1.49501D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     50     72      1     0     0   1.495D-02  -2.364D+00
#   F =  -2.3644731866535422
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.23133D+00    |proj g|=  1.02513D+01
#  This problem is unconstrained.
# At iterate    1    f= -2.25701D+00    |proj g|=  4.82764D+00
#
# At iterate    2    f= -2.25941D+00    |proj g|=  4.02472D+00
#
# At iterate    3    f= -2.26154D+00    |proj g|=  6.35112D-01
#
# At iterate    4    f= -2.26161D+00    |proj g|=  1.16941D-01
#
# At iterate    5    f= -2.26162D+00    |proj g|=  1.17237D-01
#
# At iterate    6    f= -2.26165D+00    |proj g|=  2.44172D-01
#
# At iterate    7    f= -2.26171D+00    |proj g|=  5.76869D-01
#
# At iterate    8    f= -2.26190D+00    |proj g|=  1.11262D+00
#
# At iterate    9    f= -2.26238D+00    |proj g|=  2.02905D+00
#
# At iterate   10    f= -2.26367D+00    |proj g|=  3.59595D+00
#
# At iterate   11    f= -2.26700D+00    |proj g|=  6.13005D+00
#
# At iterate   12    f= -2.27596D+00    |proj g|=  1.08242D+01
#
# At iterate   13    f= -2.29314D+00    |proj g|=  1.68189D+01
#
# At iterate   14    f= -2.31615D+00    |proj g|=  1.42159D+01
#
# At iterate   15    f= -2.33601D+00    |proj g|=  3.15813D+00
#
# At iterate   16    f= -2.33740D+00    |proj g|=  8.21897D-01
#
# At iterate   17    f= -2.33752D+00    |proj g|=  1.48045D-01
#
# At iterate   18    f= -2.33753D+00    |proj g|=  1.48300D-01
#
# At iterate   19    f= -2.33758D+00    |proj g|=  3.80874D-01
#
# At iterate   20    f= -2.33770D+00    |proj g|=  7.91615D-01
#
# At iterate   21    f= -2.33800D+00    |proj g|=  1.45557D+00
#
# At iterate   22    f= -2.33874D+00    |proj g|=  2.41386D+00
#
# At iterate   23    f= -2.34055D+00    |proj g|=  3.80409D+00
#
# At iterate   24    f= -2.34481D+00    |proj g|=  5.56729D+00
#
# At iterate   25    f= -2.35373D+00    |proj g|=  7.25621D+00
#
# At iterate   26    f= -2.37133D+00    |proj g|=  8.08081D+00
#
# At iterate   27    f= -2.39796D+00    |proj g|=  5.01048D+00
#
# At iterate   28    f= -2.41244D+00    |proj g|=  1.47281D+00
#
# At iterate   29    f= -2.41386D+00    |proj g|=  2.50061D+00
#
# At iterate   30    f= -2.41599D+00    |proj g|=  2.11578D+00
#
# At iterate   31    f= -2.41772D+00    |proj g|=  3.49257D+00
#
# At iterate   32    f= -2.41957D+00    |proj g|=  8.38234D-01
#
# At iterate   33    f= -2.42044D+00    |proj g|=  6.29412D-01
#
# At iterate   34    f= -2.42064D+00    |proj g|=  4.49505D-01
#
# At iterate   35    f= -2.42070D+00    |proj g|=  8.27903D-02
#
# At iterate   36    f= -2.42080D+00    |proj g|=  7.28834D-01
#
# At iterate   37    f= -2.42080D+00    |proj g|=  7.74009D-01
#
# At iterate   38    f= -2.42083D+00    |proj g|=  8.76598D-01
#
# At iterate   39    f= -2.42097D+00    |proj g|=  8.22270D-01
#
# At iterate   40    f= -2.42101D+00    |proj g|=  8.94200D-01
#
# At iterate   41    f= -2.42116D+00    |proj g|=  9.02974D-02
#
# At iterate   42    f= -2.42117D+00    |proj g|=  8.35185D-02
#
# At iterate   43    f= -2.42129D+00    |proj g|=  9.07012D-02
#
# At iterate   44    f= -2.42145D+00    |proj g|=  6.37669D-02
#
# At iterate   45    f= -2.42146D+00    |proj g|=  7.57628D-02
#
# At iterate   46    f= -2.42148D+00    |proj g|=  6.89910D-02
#
# At iterate   47    f= -2.42149D+00    |proj g|=  4.73999D-02
#
# At iterate   48    f= -2.42150D+00    |proj g|=  1.30408D-02
#
# At iterate   49    f= -2.42152D+00    |proj g|=  1.67742D-02
# /Users/freshliannes.rosal/anaconda3/envs/Numerical/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# At iterate   50    f= -2.42153D+00    |proj g|=  2.66263D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     50     63      1     0     0   2.663D-03  -2.422D+00
#   F =  -2.4215337585628189
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.25499D+00    |proj g|=  1.05988D+01
#  This problem is unconstrained.
# At iterate    1    f= -2.28134D+00    |proj g|=  5.06040D+00
#
# At iterate    2    f= -2.28375D+00    |proj g|=  4.35668D+00
#
# At iterate    3    f= -2.28611D+00    |proj g|=  7.02485D-01
#
# At iterate    4    f= -2.28619D+00    |proj g|=  1.12938D-01
#
# At iterate    5    f= -2.28620D+00    |proj g|=  1.13414D-01
#
# At iterate    6    f= -2.28622D+00    |proj g|=  2.25134D-01
#
# At iterate    7    f= -2.28628D+00    |proj g|=  5.34069D-01
#
# At iterate    8    f= -2.28644D+00    |proj g|=  1.06216D+00
#
# ...
#
# At iterate   31    f= -2.42892D+00    |proj g|=  2.99669D-01
#
# At iterate   32    f= -2.42915D+00    |proj g|=  1.00517D-01
#
# At iterate   33    f= -2.42921D+00    |proj g|=  1.04765D-01
#
# At iterate   34    f= -2.42938D+00    |proj g|=  6.32468D-01
#
# At iterate   35    f= -2.43106D+00    |proj g|=  8.33349D-01
#
# At iterate   36    f= -2.43544D+00    |proj g|=  5.57086D-01
#
# At iterate   37    f= -2.43769D+00    |proj g|=  1.46567D-01
#
# At iterate   38    f= -2.43920D+00    |proj g|=  4.35223D-01
#
# At iterate   39    f= -2.44021D+00    |proj g|=  2.40285D-01
#
# At iterate   40    f= -2.44054D+00    |proj g|=  1.29020D+00
#
# At iterate   41    f= -2.44087D+00    |proj g|=  5.07175D-01
#
# At iterate   42    f= -2.44107D+00    |proj g|=  3.45514D-02
#
# At iterate   43    f= -2.44108D+00    |proj g|=  8.60449D-02
#
# At iterate   44    f= -2.44109D+00    |proj g|=  1.05204D-01
#
# At iterate   45    f= -2.44112D+00    |proj g|=  6.89592D-02
#
# At iterate   46    f= -2.44113D+00    |proj g|=  8.08158D-02
#
# At iterate   47    f= -2.44115D+00    |proj g|=  7.30769D-02
#
# At iterate   48    f= -2.44118D+00    |proj g|=  2.06651D-01
#
# At iterate   49    f= -2.44120D+00    |proj g|=  3.20222D-01
# /Users/freshliannes.rosal/anaconda3/envs/Numerical/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# At iterate   50    f= -2.44127D+00    |proj g|=  2.65712D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     50     63      1     0     0   2.657D-01  -2.441D+00
#   F =  -2.4412656476794075
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.27388D+00    |proj g|=  1.18807D+01
#
# At iterate    1    f= -2.31402D+00    |proj g|=  1.92765D+00
#
# At iterate    2    f= -2.31426D+00    |proj g|=  1.55930D+00
#
# At iterate    3    f= -2.31459D+00    |proj g|=  1.30995D-01
#
# At iterate    4    f= -2.31460D+00    |proj g|=  1.31217D-01
#
# At iterate    5    f= -2.31465D+00    |proj g|=  3.31929D-01
#
# At iterate    6    f= -2.31475D+00    |proj g|=  7.18269D-01
#
# At iterate    7    f= -2.31504D+00    |proj g|=  1.46488D+00
#
# At iterate    8    f= -2.31579D+00    |proj g|=  2.65819D+00
#
# At iterate    9    f= -2.31781D+00    |proj g|=  4.70663D+00
#
# At iterate   10    f= -2.32312D+00    |proj g|=  8.32475D+00
#
# At iterate   11    f= -2.33581D+00    |proj g|=  1.39593D+01
#
# At iterate   12    f= -2.35946D+00    |proj g|=  1.98777D+01
#
# At iterate   13    f= -2.38677D+00    |proj g|=  1.28025D+01
#
# At iterate   14    f= -2.40120D+00    |proj g|=  2.29777D+00
#
# At iterate   15    f= -2.40220D+00    |proj g|=  6.08910D-01
#
# At iterate   16    f= -2.40226D+00    |proj g|=  1.46096D-01
#
# At iterate   17    f= -2.40228D+00    |proj g|=  1.45743D-01
#
# At iterate   18    f= -2.40231D+00    |proj g|=  3.81404D-01
#
# At iterate   19    f= -2.40240D+00    |proj g|=  7.68104D-01
#
# At iterate   20    f= -2.40263D+00    |proj g|=  1.41400D+00
#
# At iterate   21    f= -2.40321D+00    |proj g|=  2.38009D+00
#
# At iterate   22    f= -2.40464D+00    |proj g|=  3.78372D+00
#
# At iterate   23    f= -2.40799D+00    |proj g|=  5.62274D+00
#
# At iterate   24    f= -2.41521D+00    |proj g|=  7.55861D+00
#
# At iterate   25    f= -2.42925D+00    |proj g|=  8.64016D+00
#
# At iterate   26    f= -2.45179D+00    |proj g|=  7.05363D+00
#
# At iterate   27    f= -2.46784D+00    |proj g|=  4.29041D-01
#
# At iterate   28    f= -2.46878D+00    |proj g|=  1.63088D+00
#
# At iterate   29    f= -2.46919D+00    |proj g|=  1.48534D+00
#
# At iterate   30    f= -2.47009D+00    |proj g|=  3.79886D-01
#
# At iterate   31    f= -2.47017D+00    |proj g|=  7.60699D-02
#
# At iterate   32    f= -2.47028D+00    |proj g|=  6.09898D-01
#
# At iterate   33    f= -2.47034D+00    |proj g|=  4.80679D-01
#
# At iterate   34    f= -2.47050D+00    |proj g|=  1.53078D-01
#
# At iterate   35    f= -2.47056D+00    |proj g|=  7.63180D-02
#
# At iterate   36    f= -2.47065D+00    |proj g|=  1.50471D-01
#
# At iterate   37    f= -2.47081D+00    |proj g|=  1.00673D-01
#
# At iterate   38    f= -2.47134D+00    |proj g|=  7.33937D-01
#
# At iterate   39    f= -2.47300D+00    |proj g|=  1.59196D+00
#
# At iterate   40    f= -2.47547D+00    |proj g|=  9.81578D-01
#
# At iterate   41    f= -2.47574D+00    |proj g|=  2.43818D-02
#
# At iterate   42    f= -2.47575D+00    |proj g|=  3.00262D-02
#
# At iterate   43    f= -2.47575D+00    |proj g|=  6.05634D-03
#
# At iterate   44    f= -2.47575D+00    |proj g|=  5.98982D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     44     56      1     0     0   5.990D-03  -2.476D+00
#   F =  -2.4757462855519075
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Cross-validation RMSE for TEMPERATURE (°C): 13.368191426900708
# Cross-validation RMSE for RAINFALL (mm): 14.300111534823333
# Cross-validation RMSE for ACTUAL CONDITION: 3.860824272725582
# Cross-validation RMSE for OCCURENCE OF FLOOD: 0.4600405286435031
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.31503D-01    |proj g|=  4.68891D-01
#  This problem is unconstrained.
# At iterate    1    f=  6.79051D-01    |proj g|=  1.20815D-01
#
# At iterate    2    f=  6.54201D-01    |proj g|=  3.78961D-01
#
# At iterate    3    f=  6.13741D-01    |proj g|=  1.57722D-01
#
# At iterate    4    f=  6.01116D-01    |proj g|=  2.49762D-01
#
# At iterate    5    f=  5.95623D-01    |proj g|=  9.11498D-02
#
# At iterate    6    f=  5.89880D-01    |proj g|=  5.96516D-02
#
# At iterate    7    f=  5.85238D-01    |proj g|=  4.87490D-02
#
# At iterate    8    f=  5.83851D-01    |proj g|=  1.52436D-02
#
# At iterate    9    f=  5.83400D-01    |proj g|=  4.24086D-03
#
# At iterate   10    f=  5.83350D-01    |proj g|=  3.65228D-03
#
# At iterate   11    f=  5.83342D-01    |proj g|=  1.11515D-03
#
# At iterate   12    f=  5.83341D-01    |proj g|=  2.76089D-04
#
# At iterate   13    f=  5.83341D-01    |proj g|=  2.13512D-04
#
# At iterate   14    f=  5.83341D-01    |proj g|=  2.18203D-05
#
# At iterate   15    f=  5.83341D-01    |proj g|=  9.31955D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     15     22      1     0     0   9.320D-06   5.833D-01
#   F =  0.58334133931533727
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.19181D+00    |proj g|=  3.08464D-01
#
# At iterate    1    f=  1.15974D+00    |proj g|=  1.09591D-01
#
# At iterate    2    f=  1.14907D+00    |proj g|=  1.20768D-01
#
# At iterate    3    f=  1.11053D+00    |proj g|=  2.80203D-01
#
# At iterate    4    f=  1.08431D+00    |proj g|=  2.41462D-01
#
# At iterate    5    f=  1.04701D+00    |proj g|=  1.13061D-01
#
# At iterate    6    f=  1.03266D+00    |proj g|=  4.86308D-02
#
# At iterate    7    f=  1.02255D+00    |proj g|=  4.37348D-02
#
# At iterate    8    f=  1.02127D+00    |proj g|=  3.37872D-02
#
# At iterate    9    f=  1.01685D+00    |proj g|=  1.53727D-02
#
# At iterate   10    f=  1.01394D+00    |proj g|=  7.26339D-03
#
# At iterate   11    f=  1.01300D+00    |proj g|=  7.18707D-02
#
# At iterate   12    f=  1.01207D+00    |proj g|=  1.72210D-02
#
# At iterate   13    f=  1.01170D+00    |proj g|=  3.19957D-03
#
# At iterate   14    f=  1.01155D+00    |proj g|=  5.31969D-03
#
# At iterate   15    f=  1.01154D+00    |proj g|=  6.90502D-03
#
# At iterate   16    f=  1.01148D+00    |proj g|=  2.40214D-03
#
# At iterate   17    f=  1.01146D+00    |proj g|=  2.27912D-03
#
# At iterate   18    f=  1.01145D+00    |proj g|=  8.17312D-04
#
# At iterate   19    f=  1.01145D+00    |proj g|=  2.84914D-04
#
# At iterate   20    f=  1.01145D+00    |proj g|=  1.02046D-04
#
# At iterate   21    f=  1.01145D+00    |proj g|=  7.28675D-05
#
# At iterate   22    f=  1.01145D+00    |proj g|=  5.12792D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     22     29      1     0     0   5.128D-05   1.011D+00
#   F =   1.0114528027723420
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.60748D-01    |proj g|=  8.26168D-01
#
# At iterate    1    f=  2.35439D-01    |proj g|=  3.75647D-01
#
# At iterate    2    f=  2.31435D-01    |proj g|=  3.38845D-01
#
# At iterate    3    f=  2.28929D-01    |proj g|=  9.95570D-02
#
# At iterate    4    f=  2.22864D-01    |proj g|=  1.22423D-01
#
# At iterate    5    f=  1.84464D-01    |proj g|=  5.98623D-01
#
# At iterate    6    f=  1.72870D-01    |proj g|=  4.55754D-01
#
# At iterate    7    f=  1.54020D-01    |proj g|=  3.89747D-01
#
# At iterate    8    f=  1.48554D-01    |proj g|=  3.57623D-01
#
# At iterate    9    f=  1.28330D-01    |proj g|=  1.82972D-01
#
# At iterate   10    f=  1.10949D-01    |proj g|=  8.10088D-02
#
# At iterate   11    f=  1.01010D-01    |proj g|=  7.10818D-02
#
# At iterate   12    f=  9.97021D-02    |proj g|=  6.48054D-02
#
# At iterate   13    f=  9.47000D-02    |proj g|=  1.46558D-02
#
# At iterate   14    f=  9.17971D-02    |proj g|=  4.10806D-02
#
# At iterate   15    f=  9.06213D-02    |proj g|=  4.60121D-02
#
# At iterate   16    f=  9.00646D-02    |proj g|=  3.29607D-02
#
# At iterate   17    f=  8.99969D-02    |proj g|=  4.33251D-03
#
# At iterate   18    f=  8.99884D-02    |proj g|=  1.84812D-03
#
# At iterate   19    f=  8.99841D-02    |proj g|=  1.57742D-03
#
# At iterate   20    f=  8.99828D-02    |proj g|=  5.75631D-03
#
# At iterate   21    f=  8.99732D-02    |proj g|=  1.62704D-03
#
# At iterate   22    f=  8.99723D-02    |proj g|=  3.26608D-04
#
# At iterate   23    f=  8.99723D-02    |proj g|=  1.19607D-05
#
# At iterate   24    f=  8.99723D-02    |proj g|=  1.96714D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     24     31      1     0     0   1.967D-06   8.997D-02
#   F =   8.9972266013242652E-002
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.29514D+00    |proj g|=  1.19379D+01
#
# At iterate    1    f= -2.33364D+00    |proj g|=  1.70606D+00
#
# At iterate    2    f= -2.33384D+00    |proj g|=  1.31282D+00
#
# At iterate    3    f= -2.33407D+00    |proj g|=  1.27041D-01
#
# At iterate    4    f= -2.33410D+00    |proj g|=  1.80521D-01
#
# At iterate    5    f= -2.33419D+00    |proj g|=  5.13826D-01
#
# At iterate    6    f= -2.33455D+00    |proj g|=  1.40305D+00
#
# At iterate    7    f= -2.33536D+00    |proj g|=  2.61872D+00
#
# At iterate    8    f= -2.33773D+00    |proj g|=  4.96020D+00
#
# At iterate    9    f= -2.34360D+00    |proj g|=  8.70462D+00
#
# At iterate   10    f= -2.35824D+00    |proj g|=  1.53299D+01
#
# At iterate   11    f= -2.38129D+00    |proj g|=  1.89063D+01
#
# At iterate   12    f= -2.40822D+00    |proj g|=  1.01358D+01
#
# At iterate   13    f= -2.41691D+00    |proj g|=  1.86078D+00
#
# At iterate   14    f= -2.41752D+00    |proj g|=  3.68351D-01
#
# At iterate   15    f= -2.41756D+00    |proj g|=  1.43362D-01
#
# At iterate   16    f= -2.41757D+00    |proj g|=  1.64657D-01
#
# At iterate   17    f= -2.41762D+00    |proj g|=  4.88770D-01
#
# At iterate   18    f= -2.41773D+00    |proj g|=  9.16308D-01
#
# At iterate   19    f= -2.41805D+00    |proj g|=  1.66335D+00
#
# At iterate   20    f= -2.41883D+00    |proj g|=  2.80066D+00
#
# At iterate   21    f= -2.42070D+00    |proj g|=  4.34819D+00
#
# At iterate   22    f= -2.42512D+00    |proj g|=  6.33857D+00
#
# At iterate   23    f= -2.43409D+00    |proj g|=  8.16735D+00
#
# At iterate   24    f= -2.45066D+00    |proj g|=  8.57058D+00
#
# At iterate   25    f= -2.45522D+00    |proj g|=  8.52708D+00
#
# At iterate   26    f= -2.47821D+00    |proj g|=  8.39368D-01
#
# At iterate   27    f= -2.47874D+00    |proj g|=  1.35690D+00
#
# At iterate   28    f= -2.47943D+00    |proj g|=  8.24429D-01
#
# At iterate   29    f= -2.47958D+00    |proj g|=  2.52371D-01
#
# At iterate   30    f= -2.47963D+00    |proj g|=  1.10572D-01
#
# At iterate   31    f= -2.47969D+00    |proj g|=  4.50906D-01
#
# At iterate   32    f= -2.47980D+00    |proj g|=  4.89386D-01
#
# At iterate   33    f= -2.48108D+00    |proj g|=  6.94911D-01
#
# At iterate   34    f= -2.48374D+00    |proj g|=  1.44769D+00
#
# At iterate   35    f= -2.48490D+00    |proj g|=  8.49615D-01
#
# At iterate   36    f= -2.48703D+00    |proj g|=  2.71925D-01
#
# At iterate   37    f= -2.49104D+00    |proj g|=  9.26614D-01
#
# At iterate   38    f= -2.49318D+00    |proj g|=  5.92201D-02
#
# At iterate   39    f= -2.49432D+00    |proj g|=  5.45435D-01
#
# At iterate   40    f= -2.49483D+00    |proj g|=  4.94261D-01
#
# At iterate   41    f= -2.49494D+00    |proj g|=  1.59126D-01
#
# At iterate   42    f= -2.49496D+00    |proj g|=  1.66288D-01
#
# At iterate   43    f= -2.49496D+00    |proj g|=  1.14939D-01
#
# At iterate   44    f= -2.49496D+00    |proj g|=  1.05618D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     44     59      1     0     0   1.056D-01  -2.495D+00
#   F =  -2.4949572092246650
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# /var/folders/j3/kwprsg3s3_zf9_90gxwcknm00000gn/T/ipykernel_81713/1602292681.py:82: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   forecast_dates = pd.date_range(start=data.index.max() + pd.Timedelta(hours=8), periods=n_future, freq='8H')

# %%
# Load actual data for comparison

actual_data = pd.read_csv('Actual.csv')
actual_data['DATETIME'] = pd.to_datetime(actual_data['DATETIME'])

# Plotting the actual vs forecasted data
plt.figure(figsize=(14, 12))
print(forecast_df.index)
# Plot Temperature
plt.subplot(4, 1, 1)
plt.plot(actual_data['DATETIME'], actual_data['TEMPERATURE (°C)'], label='Actual Temperature', color='blue')
plt.plot(forecast_df.index, forecast_df['TEMPERATURE (°C)'], label='Forecasted Temperature', color='orange')
plt.title('Temperature Forecast vs Actual')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.legend()

# Plot Rainfall
plt.subplot(4, 1, 2)
plt.plot(actual_data['DATETIME'], actual_data['RAINFALL (mm)'], label='Actual Rainfall', color='blue')
plt.plot(forecast_df.index, forecast_df['RAINFALL (mm)'], label='Forecasted Rainfall', color='orange')
plt.title('Rainfall Forecast vs Actual')
plt.xlabel('Date')
plt.ylabel('Rainfall (mm)')
plt.legend()

# Plot Actual Condition
plt.subplot(4, 1, 3)
plt.plot(actual_data['DATETIME'], actual_data['ACTUAL CONDITION'], label='Actual Condition', color='blue', marker='o', markersize=2)
plt.plot(forecast_df.index, forecast_df['ACTUAL CONDITION'], label='Forecasted Condition', color='orange', marker='x', markersize=2)
plt.title('Actual Condition vs Forecasted Condition')
plt.xlabel('Date')
plt.ylabel('Actual Condition')
plt.xticks(rotation=45)
plt.legend()

# Plot Occurrence of Flood
plt.subplot(4, 1, 4)
plt.plot(actual_data['DATETIME'], actual_data['OCCURENCE OF FLOOD'], label='Actual Occurrence of Flood', color='blue', marker='o', markersize=2)
plt.plot(forecast_df.index, forecast_df['OCCURENCE OF FLOOD'], label='Forecasted Occurrence of Flood', color='orange', marker='x', markersize=2)
plt.title('Occurrence of Flood vs Forecasted Occurrence of Flood')
plt.xlabel('Date')
plt.ylabel('Occurrence of Flood')
plt.xticks(rotation=45)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# DatetimeIndex(['2024-10-01 00:00:00', '2024-10-01 08:00:00',
#                '2024-10-01 16:00:00', '2024-10-02 00:00:00',
#                '2024-10-02 08:00:00', '2024-10-02 16:00:00',
#                '2024-10-03 00:00:00', '2024-10-03 08:00:00',
#                '2024-10-03 16:00:00', '2024-10-04 00:00:00',
#                ...
#                '2024-11-22 16:00:00', '2024-11-23 00:00:00',
#                '2024-11-23 08:00:00', '2024-11-23 16:00:00',
#                '2024-11-24 00:00:00', '2024-11-24 08:00:00',
#                '2024-11-24 16:00:00', '2024-11-25 00:00:00',
#                '2024-11-25 08:00:00', '2024-11-25 16:00:00'],
#               dtype='datetime64[ns]', length=168, freq='8h')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Load the actual data from 'Actual.csv'
actual_data = pd.read_csv('Actual.csv')

# Convert 'DATETIME' columns to datetime objects for proper plotting and indexing
actual_data['DATETIME'] = pd.to_datetime(actual_data['DATETIME'])
forecast_df.index = pd.to_datetime(forecast_df.index)
print(forecast_df)

# Set the 'DATETIME' column as the index for both DataFrames
actual_data.set_index('DATETIME', inplace=True)
#forecast_df.set_index('DATETIME', inplace=True)

# Ensure that the indices align for comparison
common_index = actual_data.index.intersection(forecast_df.index)
actual_data = actual_data.loc[common_index]
forecast_df = forecast_df.loc[common_index]

# Check if the data is aligned properly
if actual_data.empty or forecast_df.empty:
    print("Error: No common indices found between actual and forecast data.")
else:
    # Calculate performance metrics
    metrics = {}
    for column in actual_data.columns:
        if column in forecast_df.columns:
            y_true = actual_data[column]
            y_pred = forecast_df[column]
            mae = mean_absolute_error(y_true, y_pred)
            rmse = np.sqrt(mean_squared_error(y_true, y_pred))
            metrics[column] = {'MAE': mae, 'RMSE': rmse}
            print(f"{column} - MAE: {mae:.2f}, RMSE: {rmse:.2f}")

    # Plot actual vs forecasted values for visual comparison
    for column in actual_data.columns:
        if column in forecast_df.columns:
            plt.figure(figsize=(12, 6))
            plt.plot(actual_data.index, actual_data[column], label='Actual', color='blue')
            plt.plot(forecast_df.index, forecast_df[column], label='Forecast', color='red', linestyle='--')
            plt.title(f'Actual vs Forecast for {column}')
            plt.xlabel('Date')
            plt.ylabel(column)
            plt.legend()
            plt.grid(True)
            plt.show()
# Out:
#                      TEMPERATURE (°C)  RAINFALL (mm)  ACTUAL CONDITION  \
# 2024-10-01 00:00:00         33.881646       0.712034         -1.465699
# 2024-10-01 08:00:00         35.003836       1.704233         -1.024025
# 2024-10-01 16:00:00         32.821880      -0.313679         -2.273189
# 2024-10-02 00:00:00         34.201467       0.676986         -1.844475
# 2024-10-02 08:00:00         35.481635       1.681094         -1.320156
# ...                               ...            ...               ...
# 2024-11-24 08:00:00               NaN            NaN               NaN
# 2024-11-24 16:00:00               NaN            NaN               NaN
# 2024-11-25 00:00:00               NaN            NaN               NaN
# 2024-11-25 08:00:00               NaN            NaN               NaN
# 2024-11-25 16:00:00               NaN            NaN               NaN
#
#                      OCCURENCE OF FLOOD
# 2024-10-01 00:00:00            0.994519
# 2024-10-01 08:00:00            0.987484
# 2024-10-01 16:00:00            1.001957
# 2024-10-02 00:00:00            0.995232
# 2024-10-02 08:00:00            0.988587
# ...                                 ...
# 2024-11-24 08:00:00                 NaN
# 2024-11-24 16:00:00                 NaN
# 2024-11-25 00:00:00                 NaN
# 2024-11-25 08:00:00                 NaN
# 2024-11-25 16:00:00                 NaN
#
# [168 rows x 4 columns]
# TEMPERATURE (°C) - MAE: 2.56, RMSE: 3.56
# RAINFALL (mm) - MAE: 5.24, RMSE: 11.45
# ACTUAL CONDITION - MAE: 7.60, RMSE: 7.93
# OCCURENCE OF FLOOD - MAE: 0.29, RMSE: 0.53

# %%
TEMPERATURE (°C) - MAE: 2.56, RMSE: 3.56
RAINFALL (mm) - MAE: 5.24, RMSE: 11.45
ACTUAL CONDITION - MAE: 7.60, RMSE: 7.93
OCCURENCE OF FLOOD - MAE: 0.29, RMSE: 0.53
